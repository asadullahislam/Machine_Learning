# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
from  sklearn.linear_model import  LinearRegression

# %%
df=pd.read_csv('nasdaq100.csv',sep=';')

# %%
df.head()
# Out:
#    Starting (USD)  Ending (USD)
# 0           16800         16500
# 1           15900         16100
# 2           15800         15300
# 3           16100         16200
# 4           16300         15700

# %%
df.isnull().sum()
# Out:
# Date              0
# Starting (USD)    0
# Ending (USD)      0
# dtype: int64

# %%
df = df.drop(columns=['Date'])

# %%
df
# Out:
#     Starting (USD)  Ending (USD)
# 0            16800         16500
# 1            15900         16100
# 2            15800         15300
# 3            16100         16200
# 4            16300         15700
# 5            16800         16400
# 6            15900         16200
# 7            15800         15500
# 8            16150         16100
# 9            16300         15800
# 10           16200         16200
# 11           16300         15700

# %%
# x = df.drop('Ending (USD)' ,axis=1)
x=df[['Starting (USD)']]

# %%
y = df[['Ending (USD)']]

# %%
y
# Out:
#     Ending (USD)
# 0          16500
# 1          16100
# 2          15300
# 3          16200
# 4          15700
# 5          16400
# 6          16200
# 7          15500
# 8          16100
# 9          15800
# 10         16200
# 11         15700

# %%
x
# Out:
#     Starting (USD)
# 0            16800
# 1            15900
# 2            15800
# 3            16100
# 4            16300
# 5            16800
# 6            15900
# 7            15800
# 8            16150
# 9            16300
# 10           16200
# 11           16300

# %%
x.mean()
# Out:
# Ending (USD)    15975.0
# dtype: float64

# %%
y.mean()
# Out:
# 15975.0

# %%
plt.scatter(df['Starting (USD)'],df['Ending (USD)'])
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
plt.scatter(x.mean(),y.mean(),color='red')

# %%
plt.scatter(df['Starting (USD)'],df['Ending (USD)'])
plt.scatter(x.mean(),y.mean(), color='red')
plt.xlabel('Starting (USD)')
plt.ylabel('Ending (USD)')
plt.title('Linear Regression')
# Out:
# Text(0.5, 1.0, 'Linear Regression')

# %%
reg = LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
x.mean()
# Out:
# Starting (USD)    16195.833333
# dtype: float64

# %%
y.mean()
# Out:
# Ending (USD)    15975.0
# dtype: float64

# %%
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
m=reg.coef_

# %%
m
# Out:
# array([[0.65258293]])

# %%
c=reg.intercept_

# %%
c
# Out:
# array([5405.87555702])

# %%
m*15800+c
# Out:
# array([[15716.68592177]])

# %%
reg.predict([[16700]])
# Out:
# C:\Users\h\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[16304.0105628]])

# %%
df['predict_y']=reg.predict(x)

# %%
plt.plot(x, reg.predict(x))

# %%
df['lose']=df['Ending (USD)']- df['predict_y']

# %%
df
# Out:
#     Starting (USD)  Ending (USD)     predict_y        lose
# 0            16800         16500  16369.268856  130.731144
# 1            15900         16100  15781.944215  318.055785
# 2            15800         15300  15716.685922 -416.685922
# 3            16100         16200  15912.460802  287.539198
# 4            16300         15700  16042.977389 -342.977389
# 5            16800         16400  16369.268856   30.731144
# 6            15900         16200  15781.944215  418.055785
# 7            15800         15500  15716.685922 -216.685922
# 8            16150         16100  15945.089949  154.910051
# 9            16300         15800  16042.977389 -242.977389
# 10           16200         16200  15977.719096  222.280904
# 11           16300         15700  16042.977389 -342.977389

# %%
reg.score(x,y)
# Out:
# 0.3577804940272571

# %%
reg.score(x,reg.)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 reg.score(x,predict_y)
#
# NameError: name 'predict_y' is not defined
